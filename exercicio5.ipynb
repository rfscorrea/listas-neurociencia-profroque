# %%
import matplotlib.pyplot as plt

# %%
j = [12, 13, 14, 15, 16, 17, 18, 19, 20]
freq = [35,67.5,75,80,85,87.5,90,92.5, 92.5]

# %%
plt.title('Gráfico fxJ para J variando de 1 em 1')
plt.plot(j, freq, 'k')
plt.ylabel('freq (Hz)')
plt.xlabel('J')
plt.grid()
plt.show()
